# %%
import numpy as np
import pandas as pd

# %%
batch_size = 64  
epochs = 100  
latent_dim = 256  # Latent dimensionality of the encoding space.(neurons)
num_samples = 10000  # Number of samples to train on.
data_path = 'fra.txt'

# %%
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()

with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')

for line in lines[:min(num_samples, len(lines) -1)]:
    input_text, target_text, _ = line.split('\t')
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)

    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

# %%
len(input_texts)
# Out:
# 10000

# %%
len(target_characters)
# Out:
# 91

# %%
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

# %%
print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 70
# Number of unique output tokens: 91
# Max sequence length for inputs: 14
# Max sequence length for outputs: 59

# %%
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char,i) for i, char in enumerate(target_characters)])

# %%
encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens))
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens))
decoder_target_data = np.zeros(
    (len(target_texts), max_decoder_seq_length, num_decoder_tokens), dtype='float32')

# %%
# input_token_index

# %%
encoder_input_data.shape
# Out:
# (10000, 14, 70)

# %%
# one hot encoding, where ever the char is present replacing there with 1.
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t+1:, input_token_index[' ']] = 1. # last character space (acts as padding)

    for t, char in enumerate(target_text):
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # target output is shifted by one step for teacher forcing.(layers)
            #Input at time t should predict the next character (t-1).
            decoder_target_data[i, t-1, target_token_index[char]] = 1.
    decoder_input_data[i, t+1:, target_token_index[' ']] = 1.
    decoder_target_data[i, t:, target_token_index[' ']] = 1.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Dense, Input

encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
encoder_states = [state_h, state_c]

# %%
decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(latent_dim, return_state=True, return_sequences=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)

decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, None, 70)          │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_layer_2 (InputLayer)    │ (None, None, 91)          │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm (LSTM)                   │ [(None, 256), (None,      │         334,848 │ input_layer[0][0]          │
# │                               │ 256), (None, 256)]        │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_2 (LSTM)                 │ [(None, None, 256),       │         356,352 │ input_layer_2[0][0],       │
# │                               │ (None, 256), (None, 256)] │                 │ lstm[0][1], lstm[0][2]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, None, 91)          │          23,387 │ lstm_2[0][0]               │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 714,587 (2.73 MB)
#  Trainable params: 714,587 (2.73 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
model.fit([encoder_input_data, decoder_input_data], decoder_target_data, 
          batch_size=batch_size, epochs = epochs, validation_split = 0.2)
# Out:
# Epoch 1/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 64s 443ms/step - accuracy: 0.7075 - loss: 1.5679 - val_accuracy: 0.7142 - val_loss: 1.0743
# Epoch 2/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 57s 454ms/step - accuracy: 0.7473 - loss: 0.9577 - val_accuracy: 0.7214 - val_loss: 0.9873
# Epoch 3/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 57s 456ms/step - accuracy: 0.7606 - loss: 0.8638 - val_accuracy: 0.7513 - val_loss: 0.8831
# Epoch 4/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 85s 477ms/step - accuracy: 0.7825 - loss: 0.7758 - val_accuracy: 0.7763 - val_loss: 0.7794
# Epoch 5/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 57s 456ms/step - accuracy: 0.8046 - loss: 0.6819 - val_accuracy: 0.7931 - val_loss: 0.7142
# Epoch 6/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 54s 435ms/step - accuracy: 0.8151 - loss: 0.6383 - val_accuracy: 0.8013 - val_loss: 0.6853
# Epoch 7/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 55s 443ms/step - accuracy: 0.8222 - loss: 0.6101 - val_accuracy: 0.8067 - val_loss: 0.6558
# Epoch 8/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 54s 428ms/step - accuracy: 0.8296 - loss: 0.5817 - val_accuracy: 0.8144 - val_loss: 0.6390
# Epoch 9/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 94s 521ms/step - accuracy: 0.8352 - loss: 0.5620 - val_accuracy: 0.8183 - val_loss: 0.6163
# Epoch 10/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 55s 436ms/step - accuracy: 0.8407 - loss: 0.5427 - val_accuracy: 0.8263 - val_loss: 0.5978
# Epoch 11/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 54s 432ms/step - accuracy: 0.8449 - loss: 0.5277 - val_accuracy: 0.8296 - val_loss: 0.5942
# Epoch 12/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 56s 446ms/step - accuracy: 0.8487 - loss: 0.5157 - val_accuracy: 0.8312 - val_loss: 0.5760
# Epoch 13/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 55s 437ms/step - accuracy: 0.8532 - loss: 0.4984 - val_accuracy: 0.8359 - val_loss: 0.5626
# Epoch 14/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 54s
# Epoch 93/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 31s 244ms/step - accuracy: 0.9545 - loss: 0.1504 - val_accuracy: 0.8757 - val_loss: 0.5097
# Epoch 94/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 34s 273ms/step - accuracy: 0.9554 - loss: 0.1471 - val_accuracy: 0.8759 - val_loss: 0.5120
# Epoch 95/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 32s 257ms/step - accuracy: 0.9564 - loss: 0.1443 - val_accuracy: 0.8751 - val_loss: 0.5149
# Epoch 96/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 33s 266ms/step - accuracy: 0.9564 - loss: 0.1435 - val_accuracy: 0.8746 - val_loss: 0.5206
# Epoch 97/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 34s 269ms/step - accuracy: 0.9572 - loss: 0.1412 - val_accuracy: 0.8750 - val_loss: 0.5223
# Epoch 98/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 37s 297ms/step - accuracy: 0.9570 - loss: 0.1419 - val_accuracy: 0.8762 - val_loss: 0.5231
# Epoch 99/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 36s 288ms/step - accuracy: 0.9577 - loss: 0.1391 - val_accuracy: 0.8744 - val_loss: 0.5286
# Epoch 100/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 33s 262ms/step - accuracy: 0.9595 - loss: 0.1353 - val_accuracy: 0.8753 - val_loss: 0.5276

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)    │ (None, None, 70)          │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_layer_3 (InputLayer)    │ (None, None, 91)          │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_1 (LSTM)                 │ [(None, 256), (None,      │         334,848 │ input_layer_1[0][0]        │
# │                               │ 256), (None, 256)]        │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_2 (LSTM)                 │ [(None, None, 256),       │         356,352 │ input_layer_3[0][0],       │
# │                               │ (None, 256), (None, 256)] │                 │ lstm_1[0][1], lstm_1[0][2] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, None, 91)          │          23,387 │ lstm_2[1][0]               │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 1,429,176 (5.45 MB)
#  Trainable params: 714,587 (2.73 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 714,589 (2.73 MB)

# %%
model.save("s2s_model.keras")

# %%
import keras
model = keras.models.load_model('s2s_model.keras')

# %%
model.layers[4]
# Out:
# <Dense name=dense_1, built=True>

# %%
# Encoder model
encoder_inputs = model.input[0]
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

# %%
# Decoder Model
decoder_inputs = model.input[1]
decoder_state_input_h = keras.Input(shape=(latent_dim,))
decoder_state_input_c = keras.Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
                                                decoder_inputs, 
                                                initial_state=decoder_states_inputs)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model([decoder_inputs] + decoder_states_inputs,
                            [decoder_outputs] + decoder_states)

# %%
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())

# %%
encoder_model.layers
# Out:
# [<InputLayer name=input_layer_1, built=True>, <LSTM name=lstm_1, built=True>]

# %%
def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq, verbose=0)

    target_seq = np.zeros((1, 1, num_decoder_tokens))
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value, verbose=0
        )

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        states_value = [h, c]
    return decoded_sentence

# %%
for seq_index in range(40):
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# -
# Input sentence: Go.
# Decoded sentence: Fais un solli.
#
# -
# Input sentence: Go.
# Decoded sentence: Fais un solli.
#
# -
# Input sentence: Go.
# Decoded sentence: Fais un solli.
#
# -
# Input sentence: Go.
# Decoded sentence: Fais un solli.
#
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# -
# Input sentence: Who?
# Decoded sentence: Suis-je tonten ?
#
# -
# Input sentence: Wow!
# Decoded sentence: Faites-moi !
#
# -
# Input sentence: Wow!
# Decoded sentence: Faites-moi !
#
# -
# Input sentence: Wow!
# Decoded sentence: Faites-moi !
#
# -
# Input sentence: Duck!
# Decoded sentence: Fais la poil!
#
# -
# Input sentence: Duck!
# Decoded sentence: Fais la poil!
#
# -
# Input sentence: Duck!
# Decoded sentence: Fais la poil!
#
# -
# Input sentence: Fire!
# Decoded sentence: Au entanc !
#
# -
# Input sentence: Help!
# Decoded sentence: Ailez !
#
# -
# Input sentence: Hide.
# Decoded sentence: Cache-toi.
#
# -
# Input sentence: Hide.
# Decoded sentence: Cache-toi.
#
# -
# Input sentence: Jump!
# Decoded sentence: Saute.
#
# -
# Input sentence: Jump.
# Decoded sentence: Saute.
#
# -
# Input sentence: Stop!
# Decoded sentence: Attends !
#
# -
# Input sentence: Stop!
# Decoded sentence: Attends !
#
# -
# Input sentence: Stop!
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attendez !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attendez !
